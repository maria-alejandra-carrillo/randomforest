# %%
dat <- read.table('/Users/mariaac/interaction/intnet_filled_devadd.txt', sep='\t', header=TRUE)

# %%
regres_model = model <- lm(formula= lsb_123 ~ cos(phi) + halo_dists + relative_velocity + Nmajorint, data=dat)

# %%
plot(lm(formula= lsb_123 ~ cos(phi) + halo_dists + relative_velocity + Nmajorint, data=dat))
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
summary(model)
# Out:
# Call:
# lm(formula = lsb_123 ~ cos(phi) + halo_dists + relative_velocity +
#     Nmajorint, data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.6713 -0.3655 -0.3228  0.6104  0.8865
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        3.321e-01  3.836e-03  86.554  < 2e-16 ***
# cos(phi)          -1.918e-02  4.236e-03  -4.527 6.00e-06 ***
# halo_dists         2.231e-05  9.104e-07  24.501  < 2e-16 ***
# relative_velocity -8.367e-05  1.967e-05  -4.253 2.11e-05 ***
# Nmajorint         -4.083e-03  9.581e-05 -42.615  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4697 on 70894 degrees of freedom
# Multiple R-squared:  0.03336,	Adjusted R-squared:  0.03331
# F-statistic: 611.7 on 4 and 70894 DF,  p-value: < 2.2e-16
